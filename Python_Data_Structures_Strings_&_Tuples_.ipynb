# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya-DataAnalystPortfolio/Python-Fundaments/blob/main/Python_Data_Structures_Strings_%26_Tuples_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Strings (Concatenation, Slicing and Other methods) :**

# %% [markdown]
# **1. String Concatenation:**
# Write a Python program that takes two strings i.e string 1 “Hello ”, string 2 get name as
# input from the user and concatenates them together. Display the concatenated string as
# the output.

# %%
String_1 = "Hello"
String_2 = input("Enter your name:")

String = String_1 + " " + String_2
print(String)
# Out:
# Enter your name:Divya
# Hello Divya

# %% [markdown]
# Now concatenate string 3 “, welcome to Python programming” to the existing string and display the output string.

# %%
String_3 = "Welcome to Python Programming"
Full_String = f"{String}, {String_3}"
print(Full_String)
# Out:
# Hello Divya, Welcome to Python Programming

# %% [markdown]
# **2. String Slicing and Indexing:**
#
#
# Write a Python program using the above concatenated string as input and performs the following tasks:

# %%
# a. Print the first character of the string.
print(f"Last Character: {Full_String[0]}")

# b. Print the last character of the string.
print(f"Last Character: {Full_String[-1]}")

# c. Print the first 5 characters of the string.
print(f"First 5 characters: {Full_String[0:5]}")

# d. Print the last 11 characters of the string.
print(f"Last 11 characters: {Full_String[-11:]}")

# e. Print the string in reverse.
print(f"String in reverse: {Full_String[::-1]}")

# f. Use slicing and print the word “Python” from the existing string.
print(f"Sliced word 'Python': {Full_String[24:30]}")
# Out:
# Last Character: H
# Last Character: g
# First 5 characters: Hello
# Last 11 characters: Programming
# String in reverse: gnimmargorP nohtyP ot emocleW ,ayviD olleH
# Sliced word 'Python': Python

# %% [markdown]
# **3. String Methods:**
#
# Write a Python program that takes a string, strM = “Python beginner tutorial” and perform the following tasks:

# %%
strM = "Python beginner tutorial"

#a. Convert the sentence to uppercase.
print(f"Upper = {strM.upper()}")

# b. Convert the sentence to lowercase.
print(f"Lower = {strM.lower()}")

# c. Use Capitalize and return the sentence to the original input form.
print(f"Capitalize = {strM.capitalize()}")

# d. Count the total number of occurrences of character ‘t’ in the string.
print(f"Count 't' = {strM.count('t')}")

# e. Replace all occurrences of “Python” with “Machine Learning” in the input string strM = “Python beginner tutorial”
print(f"Replace Python = {strM.replace("Python", "Machine Learning")}")
# Out:
# Upper = PYTHON BEGINNER TUTORIAL
# Lower = python beginner tutorial
# Capitalize = Python beginner tutorial
# Count 't' = 3
# Replace Python = Machine Learning beginner tutorial

# %% [markdown]
# **Tuples (Creation, Modification and Access) :**
#
# Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60):

# %%
Tuple_1 = (10, 20, 30)
Tuple_2 = (40, 50, 60)

# a. Concatenate the two tuples and store it in “t_combine”
T_combine = Tuple_1 + Tuple_2
print(f"Concatenated Tuples = {T_combine}")

# b. Repeat the elements of “t_combine” 3 times
print(f"Repeat 3 times = {T_combine*3}")

# c. Access the 3rd element from “t_combine”
print(f"3rd Element = {T_combine[2]}")

# d. Access the first three elements from “t_combine”
print(f"First 3 Elements = {T_combine[0:3]}")

# e. Access the last three elements from “t_combine”
print(f"Last 3 elements = {T_combine[-3:]}")
# Out:
# Concatenated Tuples = (10, 20, 30, 40, 50, 60)
# Repeat 3 times = (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 3rd Element = 30
# First 3 Elements = (10, 20, 30)
# Last 3 elements = (40, 50, 60)
